# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
import sys
import matplotlib.pyplot as plt
from pybloom import BloomFilter

CONST_A = 0
CONST_C = 1
CONST_G = 2
CONST_T = 3

CONST_NT_MAP = ['A', 'C', 'G', 'T']

def reverse_complement(seq) :
    rc_seq = ''
    for i in range(0, len(seq)) :
        if seq[i] == 'A' :
            rc_seq = 'T' + rc_seq
        elif seq[i] == 'C' :
            rc_seq = 'G' + rc_seq
        elif seq[i] == 'G' :
            rc_seq = 'C' + rc_seq
        elif seq[i] == 'T' :
            rc_seq = 'A' + rc_seq
    return rc_seq

def remove_duplicates_round(df,hamm_thres=4,merge_counts=False):
    seqs = list(df.Seq.values)
    counts = list(df.Counts.values)
    c = 0
    while c<(len(counts)-1):
        if(distance(seqs[c],seqs[c+1]))<hamm_thres:
            if(counts[c]>counts[c+1]):
                if(merge_counts):
                    counts[c]+=counts[c+1]
                del counts[c+1],seqs[c+1]
            else:
                if(merge_counts):
                    counts[c+1]+=counts[c]
                del counts[c],seqs[c]
        else:
            c+=1
    return pd.DataFrame({'Seq':seqs,'Counts':counts})

def remove_all_duplicates(sequences,counts,hamming_thresh=4,merge_counts=False):
    df = pd.DataFrame({'Seq':sequences,'Counts':counts})
    seq_len = len(sequences[0])
    
    print('Removing hamming neighbors on dimension:')
    
    for i in range(seq_len):
        df = df.ix[(df.Seq.str.slice(seq_len-i)+df.Seq.str.slice(i)).sort_values().index]
        df = remove_duplicates_round(df,hamm_thres=hamming_thresh,merge_counts=merge_counts)
        print(i)
    return df



def key_shifted_sequence(seq, i) :
    seq_i = seq[i:] + seq[0:i]
    return seq_i

def hamming_cluster_library(sequences, counts, total_counts, hamming_thresh=4) :
    seq_len = len(sequences[0])
    
    print('Removing hamming neighbors on dimension:')
    for i in range(seq_len) :
        sequences = sorted(sequences, key=lambda x: key_shifted_sequence(x, i))
        
        sequences, counts = hamming_cluster_round(sequences, counts, total_counts, hamming_thresh)
        print(i)
    return sequences, counts

def hamming_cluster_round(seqs, counts, total_counts, hamming_thresh) :
    removed_set = {}
    
    i = 0
    j = 1
    while j < len(seqs) :
        
        if distance(seqs[i], seqs[j]) < hamming_thresh:
            
            if total_counts[seqs[i]] >= total_counts[seqs[j]] :
                removed_set[seqs[j]] = True
                for k in range(len(counts)) :
                    counts[k][seqs[i]] += counts[k][seqs[j]]
                
                j += 1
            else :
                removed_set[seqs[i]] = True
                for k in range(len(counts)) :
                    counts[k][seqs[j]] += counts[k][seqs[i]]
                
                i = j
                j += 1
                
        else :
            i = j
            j += 1
    
    hamming_seqs = []
    for seq in seqs :
        if seq not in removed_set :
            hamming_seqs.append(seq)
    return hamming_seqs, counts

def distance(astring, bstring) :
    distance = 0
    
    limit = len(astring)
    diff = len(bstring) - len(astring)
    if len(bstring) < len(astring) :
        limit = len(bstring)
        diff = len(astring) - len(bstring)
    
    for i in range(limit) :
        if astring[i] != bstring[i] :
            distance += 1
    return distance + diff

def is_misprimed(seq, start_pos) :
    
    if start_pos >= len(seq) - 10 :
        return False
    
    a_count = 0
    
    if seq[start_pos - 1] == 'A' :
        a_count += 1
    if seq[start_pos - 1] == 'A' and seq[start_pos - 2] == 'A' :
        a_count += 1
    
    for i in range(0, 10) :
        if seq[start_pos + i] == 'A' :
            a_count += 1
        
        if i < 4 and a_count >= 3 :
            return True
        if i < 7 and a_count >= 4 :
            return True
        elif i < 8 and a_count >= 5 :
            return True
        elif i < 9 and a_count >= 6 :
            return True
    return False

# %%
dna_file = pd.read_csv('apa_sym_prx_dna_hamming_20160825.csv',sep=',')

dna_barcode_list = list(dna_file.barcode)
dna_sequence_list = list(dna_file.sequence)

dna_barcode_map = {}
dna_sequence_map = {}
dna_identity_map = {}

for i in range(0, len(dna_barcode_list)) :
    dna_barcode_map[dna_barcode_list[i]] = dna_barcode_list[i]
    dna_sequence_map[dna_barcode_list[i]] = dna_sequence_list[i]
    dna_identity_map[dna_barcode_list[i]] = i

# %%
#Generate UMI Blooms filters

umi_blooms = {}

mer6_map = {}

bases = 'ACGTN'
i = 0
for base1 in bases:
    for base2 in bases:
        for base3 in bases:
            for base4 in bases:
                for base5 in bases:
                    for base6 in bases:
                        umi = base1 + base2 + base3 + base4 + base5 + base6
                        #f = BloomFilter(capacity=len(dna_identity_map), error_rate=0.001)
                        #umi_blooms[umi] = f
                        mer6_map[umi] = i
                        i += 1

print(len(umi_blooms))
print(len(mer6_map))
# Out:
# 0
# 15625

# %%
rna_file = open('apa_sym_prx_mapped_rna_20160916.csv', 'r')
count = 0

mapped_count = {}
mapped_proximal1_count = {}
mapped_proximal2_count = {}
mapped_distal_count = {}

mapped_umi_map = {}

total_mapped_count = 0
total_valid_aligns = 0
total_unique_umi_count = 0
total_mapped_proximal1_count = 0
total_mapped_proximal2_count = 0
total_mapped_distal_count = 0

proximal1_limits = [56, 70]
proximal2_limits = [140, 154]
distal_limits = [304, 324]


print('Mapping RNA reads to DNA members.')


rna_file.readline()

i = 0

for k in range(1):
    for line in rna_file :
        i += 1
        if line == None :
            break
        
        lineparts = line.split(',')
        if len(lineparts) != 5 :
            break
        
        barcode = lineparts[0]
        umi = lineparts[1]
        polya_pos = int(lineparts[3])
        align_score = float(lineparts[4])
        
        seq = dna_sequence_map[barcode]
        
        if seq not in mapped_count:
            mapped_count[seq] = 0
            mapped_proximal1_count[seq] = 0
            mapped_proximal2_count[seq] = 0
            mapped_distal_count[seq] = 0
        
        if align_score >= 60 and not is_misprimed(seq, polya_pos + 1) :
            total_valid_aligns += 1
            
            if dna_identity_map[barcode] not in mapped_umi_map :
                mapped_umi_map[dna_identity_map[barcode]] = {}

            is_dup_umi = False

            #Exact match UMI
            #if umi in mapped_umi_map[seq] :
            #if dna_identity_map[barcode] in umi_blooms[umi] :
            #    is_dup_umi = True
            if mer6_map[umi] in mapped_umi_map[dna_identity_map[barcode]] :
                is_dup_umi = True
            
            if is_dup_umi == False :
                total_unique_umi_count += 1
                mapped_umi_map[dna_identity_map[barcode]][mer6_map[umi]] = True
                #umi_blooms[umi].add(dna_identity_map[barcode])
                
                if polya_pos >= proximal1_limits[0] and polya_pos <= proximal1_limits[1] :
                    total_mapped_proximal1_count += 1

                    mapped_proximal1_count[seq] += 1
                    mapped_count[seq] += 1
                elif polya_pos >= proximal2_limits[0] and polya_pos <= proximal2_limits[1] :
                    total_mapped_proximal2_count += 1

                    mapped_proximal2_count[seq] += 1
                    mapped_count[seq] += 1
                elif polya_pos >= distal_limits[0] and polya_pos <= distal_limits[1] :
                    total_mapped_distal_count += 1

                    mapped_distal_count[seq] += 1
                    mapped_count[seq] += 1
        
        
        if count % 1000000 == 0:
            print(count)
            print(str(total_valid_aligns) + ' valid read align count')
            print(str(total_unique_umi_count) + ' unique umi count')
            print(str(len(mapped_count)) + ' mapped unique library members')
            print(str(total_mapped_proximal1_count) + ' mapped proximal 1 RNA reads')
            print(str(total_mapped_proximal2_count) + ' mapped proximal 2 RNA reads')
            print(str(total_mapped_distal_count) + ' mapped distal RNA reads')
        count += 1
    
print('COMPLETE')
print(str(len(mapped_count)) + ' mapped unique library members')
print(str(total_mapped_proximal1_count) + ' mapped proximal 1 RNA reads')
print(str(total_mapped_proximal2_count) + ' mapped proximal 2 RNA reads')
print(str(total_mapped_distal_count) + ' mapped distal RNA reads')

rna_file.close()

mapped_seq_list = []
mapped_proximal1_list = []
mapped_proximal2_list = []
mapped_distal_list = []
mapped_count_list = []

for seq in mapped_count :
    if mapped_count[seq] > 0 :
        mapped_seq_list.append(seq)
        mapped_proximal1_list.append(mapped_proximal1_count[seq])
        mapped_proximal2_list.append(mapped_proximal2_count[seq])
        mapped_distal_list.append(mapped_distal_count[seq])
        mapped_count_list.append(mapped_count[seq])

print(str(len(mapped_seq_list)) + ' kept library members')

df = pd.DataFrame({'sequence'  : mapped_seq_list,
                   'proximal1_count'  : mapped_proximal1_list,
                   'proximal2_count'  : mapped_proximal2_list,
                   'distal_count' : mapped_distal_list,
                   'total_count' : mapped_count_list})

df = df.sort_values('total_count')

print(len(df))

new_columns = ['sequence', 'proximal1_count', 'proximal2_count', 'distal_count', 'total_count']
df.to_csv('apa_sym_prx_library_20160916.csv', sep=',', header=True, columns=new_columns, index=False)
# Out:
# Mapping RNA reads to DNA members.
# 0
# 0 valid read align count
# 0 unique umi count
# 1 mapped unique library members
# 0 mapped proximal 1 RNA reads
# 0 mapped proximal 2 RNA reads
# 0 mapped distal RNA reads
# 1000000
# 79615 valid read align count
# 79615 unique umi count
# 432420 mapped unique library members
# 11369 mapped proximal 1 RNA reads
# 3084 mapped proximal 2 RNA reads
# 51527 mapped distal RNA reads
# 2000000
# 174854 valid read align count
# 174854 unique umi count
# 628170 mapped unique library members
# 32025 mapped proximal 1 RNA reads
# 8153 mapped proximal 2 RNA reads
# 95766 mapped distal RNA reads
# 3000000
# 297591 valid read align count
# 297591 unique umi count
# 783576 mapped unique library members
# 52844 mapped proximal 1 RNA reads
# 13686 mapped proximal 2 RNA reads
# 163366 mapped distal RNA reads
# 4000000
# 426214 valid read align count
# 426214 unique umi count
# 911083 mapped unique library members
# 73762 mapped proximal 1 RNA reads
# 19443 mapped proximal 2 RNA reads
# 236235 mapped distal RNA reads
# 5000000
# 558834 valid read align count
# 558834 unique umi count
# 1019801 mapped unique library members
# 94599 mapped proximal 1 RNA reads
# 25307 mapped proximal 2 RNA reads
# 313069 mapped distal RNA reads
# 6000000
# 689447 valid read align count
# 689447 unique umi count
# 1111917 mapped unique library members
# 115323 mapped proximal 1 RNA reads
# 31136 mapped proximal 2 RNA reads
# 387690 mapped distal RNA reads
# 7000000
# 818670 valid read align count
# 818670 unique umi count
# 1192581 mapped unique library members
# 135973 mapped proximal 1 RNA reads
# 36876 mapped proximal 2 RNA reads
# 461443 mapped distal RNA reads
# 8000000
# 951830 valid read align count
# 951830 unique umi count
# 1265777 mapped unique library members
# 156478 mapped proximal 1 RNA reads
# 42648 mapped proximal 2 RNA reads
# 538787 mapped distal RNA reads
# 9000000
# 1051153 valid read align count
# 1051153 unique umi count
# 1338123 mapped unique library members
# 171046 mapped proximal 1 RNA reads
# 46694 mapped proximal 2 RNA reads
# 600717 mapped distal RNA reads
# 10000000
# 1125619 valid read align count
# 1125619 unique umi count
# 1383806 mapped unique library members
# 187851 mapped proximal 1 RNA reads
# 50735 mapped proximal 2 RNA reads
# 635091 mapped distal RNA reads
# 11000000
# 1238855 valid read align count
# 1238855 unique umi count
# 1431525 mapped unique library members
# 208915 mapped proximal 1 RNA reads
# 56308 mapped proximal 2 RNA reads
# 693227 mapped distal RNA reads
# 12000000
# 1368468 valid read align count
# 1368468 unique umi count
# 1480135 mapped unique library members
# 229655 mapped proximal 1 RNA reads
# 62150 mapped proximal 2 RNA reads
# 767129 mapped distal RNA reads
# 13000000
# 1503444 valid read align count
# 1503444 unique umi count
# 1526066 mapped unique library members
# 250259 mapped proximal 1 RNA reads
# 67964 mapped proximal 2 RNA reads
# 846583 mapped distal RNA reads
# 14000000
# 1641715 valid read align count
# 1641715 unique umi count
# 1569790 mapped unique library members
# 270801 mapped proximal 1 RNA reads
# 73566 mapped proximal 2 RNA reads
# 929518 mapped distal RNA reads
# 15000000
# 1780488 valid read align count
# 1780488 unique umi count
# 1609835 mapped unique library members
# 291200 mapped proximal 1 RNA reads
# 79393 mapped proximal 2 RNA reads
# 1012653 mapped distal RNA reads
# 16000000
# 1918863 valid read align count
# 1918863 unique umi count
# 1646691 mapped unique library members
# 311413 mapped proximal 1 RNA reads
# 85195 mapped proximal 2 RNA reads
# 1095899 mapped distal RNA reads
# 17000000
# 2057698 valid read align count
# 2057698 unique umi count
# 1684517 mapped unique library members
# 330299 mapped proximal 1 RNA reads
# 90377 mapped proximal 2 RNA reads
# 1184271 mapped distal RNA reads
# 18000000
# 2139911 valid read align count
# 2139911 unique umi count
# 1714734 mapped unique library members
# 342206 mapped proximal 1 RNA reads
# 93653 mapped proximal 2 RNA reads
# 1235848 mapped distal RNA reads
# 19000000
# 2225396 valid read align count
# 2225396 unique umi count
# 1737101 mapped unique library members
# 360486 mapped proximal 1 RNA reads
# 98159 mapped proximal 2 RNA reads
# 1276186 mapped distal RNA reads
# 20000000
# 2350938 valid read align count
# 2350938 unique umi count
# 1762878 mapped unique library members
# 381226 mapped proximal 1 RNA reads
# 103747 mapped proximal 2 RNA reads
# 1346694 mapped distal RNA reads
# 21000000
# 2485449 valid read align count
# 2485449 unique umi count
# 1789163 mapped unique library members
# 401660 mapped proximal 1 RNA reads
# 109391 mapped proximal 2 RNA reads
# 1426573 mapped distal RNA reads
# 22000000
# 2623923 valid read align count
# 2623923 unique umi count
# 1814158 mapped unique library members
# 421948 mapped proximal 1 RNA reads
# 115195 mapped proximal 2 RNA reads
# 1510000 mapped distal RNA reads
# 23000000
# 2760134 valid read align count
# 2760134 unique umi count
# 1836988 mapped unique library members
# 442513 mapped proximal 1 RNA reads
# 120952 mapped proximal 2 RNA reads
# 1590891 mapped distal RNA reads
# 24000000
# 2896105 valid read align count
# 2896105 unique umi count
# 1858676 mapped unique library members
# 462828 mapped proximal 1 RNA reads
# 126708 mapped proximal 2 RNA reads
# 1671580 mapped distal RNA reads
# 25000000
# 3036291 valid read align count
# 3036291 unique umi count
# 1879686 mapped unique library members
# 483282 mapped proximal 1 RNA reads
# 132398 mapped proximal 2 RNA reads
# 1756778 mapped distal RNA reads
# 26000000
# 3145904 valid read align count
# 3145904 unique umi count
# 1899724 mapped unique library members
# 500009 mapped proximal 1 RNA reads
# 136751 mapped proximal 2 RNA reads
# 1824667 mapped distal RNA reads
# 27000000
# 3236746 valid read align count
# 3236746 unique umi count
# 1912486 mapped unique library members
# 520475 mapped proximal 1 RNA reads
# 141601 mapped proximal 2 RNA reads
# 1865343 mapped distal RNA reads
# 28000000
# 3349314 valid read align count
# 3349314 unique umi count
# 1926727 mapped unique library members
# 541488 mapped proximal 1 RNA reads
# 147140 mapped proximal 2 RNA reads
# 1922388 mapped distal RNA reads
# 29000000
# 3474799 valid read align count
# 3474799 unique umi count
# 1941848 mapped unique library members
# 562199 mapped proximal 1 RNA reads
# 152821 mapped proximal 2 RNA reads
# 1992043 mapped distal RNA reads
# 30000000
# 3602010 valid read align count
# 3602010 unique umi count
# 1956091 mapped unique library members
# 582908 mapped proximal 1 RNA reads
# 158560 mapped proximal 2 RNA reads
# 2063354 mapped distal RNA reads
# 31000000
# 3730374 valid read align count
# 3730374 unique umi count
# 1969960 mapped unique library members
# 603501 mapped proximal 1 RNA reads
# 164323 mapped proximal 2 RNA reads
# 2135449 mapped distal RNA reads
# 32000000
# 3853288 valid read align count
# 3853288 unique umi count
# 1982354 mapped unique library members
# 624434 mapped proximal 1 RNA reads
# 170136 mapped proximal 2 RNA reads
# 2202033 mapped distal RNA reads
# 33000000
# 3975347 valid read align count
# 3975347 unique umi count
# 1994052 mapped unique library members
# 645614 mapped proximal 1 RNA reads
# 175985 mapped proximal 2 RNA reads
# 2267273 mapped distal RNA reads
# 34000000
# 4104925 valid read align count
# 4104925 unique umi count
# 2006263 mapped unique library members
# 666042 mapped proximal 1 RNA reads
# 181545 mapped proximal 2 RNA reads
# 2341670 mapped distal RNA reads
# 35000000
# 4181836 valid read align count
# 4181836 unique umi count
# 2017755 mapped unique library members
# 680651 mapped proximal 1 RNA reads
# 185025 mapped proximal 2 RNA reads
# 2384305 mapped distal RNA reads
# 36000000
# 4273993 valid read align count
# 4273993 unique umi count
# 2025518 mapped unique library members
# 702196 mapped proximal 1 RNA reads
# 190170 mapped proximal 2 RNA reads
# 2421731 mapped distal RNA reads
# 37000000
# 4386516 valid read align count
# 4386516 unique umi count
# 2034815 mapped unique library members
# 723473 mapped proximal 1 RNA reads
# 195855 mapped proximal 2 RNA reads
# 2477886 mapped distal RNA reads
# 38000000
# 4513966 valid read align count
# 4513966 unique umi count
# 2044827 mapped unique library members
# 744448 mapped proximal 1 RNA reads
# 201578 mapped proximal 2 RNA reads
# 2548876 mapped distal RNA reads
# 39000000
# 4643695 valid read align count
# 4643695 unique umi count
# 2054763 mapped unique library members
# 764999 mapped proximal 1 RNA reads
# 207480 mapped proximal 2 RNA reads
# 2622832 mapped distal RNA reads
# 40000000
# 4775379 valid read align count
# 4775379 unique umi count
# 2064266 mapped unique library members
# 785967 mapped proximal 1 RNA reads
# 213409 mapped proximal 2 RNA reads
# 2698128 mapped distal RNA reads
# 41000000
# 4907691 valid read align count
# 4907691 unique umi count
# 2073508 mapped unique library members
# 806881 mapped proximal 1 RNA reads
# 219318 mapped proximal 2 RNA reads
# 2774146 mapped distal RNA reads
# 42000000
# 5038749 valid read align count
# 5038749 unique umi count
# 2082202 mapped unique library members
# 827445 mapped proximal 1 RNA reads
# 225185 mapped proximal 2 RNA reads
# 2849445 mapped distal RNA reads
# 43000000
# 5162438 valid read align count
# 5162438 unique umi count
# 2092127 mapped unique library members
# 845724 mapped proximal 1 RNA reads
# 230249 mapped proximal 2 RNA reads
# 2924024 mapped distal RNA reads
# 44000000
# 5256334 valid read align count
# 5256334 unique umi count
# 2099726 mapped unique library members
# 861481 mapped proximal 1 RNA reads
# 234407 mapped proximal 2 RNA reads
# 2978700 mapped distal RNA reads
# 45000000
# 5349806 valid read align count
# 5349806 unique umi count
# 2104999 mapped unique library members
# 882866 mapped proximal 1 RNA reads
# 239645 mapped proximal 2 RNA reads
# 3017684 mapped distal RNA reads
# 46000000
# 5467420 valid read align count
# 5467420 unique umi count
# 2111547 mapped unique library members
# 903865 mapped proximal 1 RNA reads
# 245349 mapped proximal 2 RNA reads
# 3079497 mapped distal RNA reads
# 47000000
# 5599782 valid read align count
# 5599782 unique umi count
# 2118908 mapped unique library members
# 924654 mapped proximal 1 RNA reads
# 251048 mapped proximal 2 RNA reads
# 3155976 mapped distal RNA reads
# 48000000
# 5733428 valid read align count
# 5733428 unique umi count
# 2126069 mapped unique library members
# 945310 mapped proximal 1 RNA reads
# 256868 mapped proximal 2 RNA reads
# 3233813 mapped distal RNA reads
# 49000000
# 5866152 valid read align count
# 5866152 unique umi count
# 2132802 mapped unique library members
# 965913 mapped proximal 1 RNA reads
# 262625 mapped proximal 2 RNA reads
# 3310867 mapped distal RNA reads
# 50000000
# 5997407 valid read align count
# 5997407 unique umi count
# 2139290 mapped unique library members
# 986877 mapped proximal 1 RNA reads
# 268401 mapped proximal 2 RNA reads
# 3385903 mapped distal RNA reads
# 51000000
# 6129863 valid read align count
# 6129863 unique umi count
# 2145601 mapped unique library members
# 1007630 mapped proximal 1 RNA reads
# 274141 mapped proximal 2 RNA reads
# 3462543 mapped distal RNA reads
# 52000000
# 6274188 valid read align count
# 6274188 unique umi count
# 2152470 mapped unique library members
# 1027843 mapped proximal 1 RNA reads
# 279882 mapped proximal 2 RNA reads
# 3552130 mapped distal RNA reads
# 53000000
# 6375735 valid read align count
# 6375735 unique umi count
# 2156626 mapped unique library members
# 1049656 mapped proximal 1 RNA reads
# 285511 mapped proximal 2 RNA reads
# 3596988 mapped distal RNA reads
# 54000000
# 6478562 valid read align count
# 6478562 unique umi count
# 2160586 mapped unique library members
# 1071102 mapped proximal 1 RNA reads
# 291006 mapped proximal 2 RNA reads
# 3643433 mapped distal RNA reads
# 55000000
# 6586707 valid read align count
# 6586707 unique umi count
# 2164846 mapped unique library members
# 1092532 mapped proximal 1 RNA reads
# 296773 mapped proximal 2 RNA reads
# 3695030 mapped distal RNA reads
# 56000000
# 6696870 valid read align count
# 6696870 unique umi count
# 2169056 mapped unique library members
# 1113661 mapped proximal 1 RNA reads
# 302517 mapped proximal 2 RNA reads
# 3749007 mapped distal RNA reads
# 57000000
# 6806455 valid read align count
# 6806455 unique umi count
# 2173289 mapped unique library members
# 1134751 mapped proximal 1 RNA reads
# 308113 mapped proximal 2 RNA reads
# 3802772 mapped distal RNA reads
# 58000000
# 6906044 valid read align count
# 6906044 unique umi count
# 2177262 mapped unique library members
# 1155229 mapped proximal 1 RNA reads
# 313271 mapped proximal 2 RNA reads
# 3852121 mapped distal RNA reads
# 59000000
# 6974088 valid read align count
# 6974088 unique umi count
# 2181696 mapped unique library members
# 1168653 mapped proximal 1 RNA reads
# 316639 mapped proximal 2 RNA reads
# 3888105 mapped distal RNA reads
# 60000000
# 7105671 valid read align count
# 7105671 unique umi count
# 2187151 mapped unique library members
# 1187533 mapped proximal 1 RNA reads
# 321652 mapped proximal 2 RNA reads
# 3969954 mapped distal RNA reads
# 61000000
# 7216343 valid read align count
# 7216343 unique umi count
# 2190960 mapped unique library members
# 1208667 mapped proximal 1 RNA reads
# 327253 mapped proximal 2 RNA reads
# 4024510 mapped distal RNA reads
# 62000000
# 7326841 valid read align count
# 7326841 unique umi count
# 2194569 mapped unique library members
# 1229960 mapped proximal 1 RNA reads
# 332801 mapped proximal 2 RNA reads
# 4079231 mapped distal RNA reads
# 63000000
# 7442576 valid read align count
# 7442576 unique umi count
# 2198379 mapped unique library members
# 1251226 mapped proximal 1 RNA reads
# 338596 mapped proximal 2 RNA reads
# 4138543 mapped distal RNA reads
# 64000000
# 7563007 valid read align count
# 7563007 unique umi count
# 2202254 mapped unique library members
# 1272047 mapped proximal 1 RNA reads
# 344259 mapped proximal 2 RNA reads
# 4203474 mapped distal RNA reads
# 65000000
# 7683717 valid read align count
# 7683717 unique umi count
# 2206170 mapped unique library members
# 1292569 mapped proximal 1 RNA reads
# 349817 mapped proximal 2 RNA reads
# 4269841 mapped distal RNA reads
# 66000000
# 7793581 valid read align count
# 7793581 unique umi count
# 2209844 mapped unique library members
# 1311691 mapped proximal 1 RNA reads
# 354731 mapped proximal 2 RNA reads
# 4331043 mapped distal RNA reads
# 67000000
# 7872939 valid read align count
# 7872939 unique umi count
# 2213836 mapped unique library members
# 1325662 mapped proximal 1 RNA reads
# 357855 mapped proximal 2 RNA reads
# 4377857 mapped distal RNA reads
# 68000000
# 8002901 valid read align count
# 8002901 unique umi count
# 2217530 mapped unique library members
# 1346116 mapped proximal 1 RNA reads
# 363427 mapped proximal 2 RNA reads
# 4452966 mapped distal RNA reads
# 69000000
# 8105805 valid read align count
# 8105805 unique umi count
# 2220078 mapped unique library members
# 1367606 mapped proximal 1 RNA reads
# 369111 mapped proximal 2 RNA reads
# 4499130 mapped distal RNA reads
# 70000000
# 8212575 valid read align count
# 8212575 unique umi count
# 2222732 mapped unique library members
# 1389033 mapped proximal 1 RNA reads
# 374755 mapped proximal 2 RNA reads
# 4549083 mapped distal RNA reads
# 71000000
# 8324492 valid read align count
# 8324492 unique umi count
# 2225397 mapped unique library members
# 1410084 mapped proximal 1 RNA reads
# 380437 mapped proximal 2 RNA reads
# 4604915 mapped distal RNA reads
# 72000000
# 8440244 valid read align count
# 8440244 unique umi count
# 2228282 mapped unique library members
# 1431062 mapped proximal 1 RNA reads
# 386137 mapped proximal 2 RNA reads
# 4664846 mapped distal RNA reads
# 73000000
# 8554049 valid read align count
# 8554049 unique umi count
# 2231062 mapped unique library members
# 1451966 mapped proximal 1 RNA reads
# 391573 mapped proximal 2 RNA reads
# 4723541 mapped distal RNA reads
# 74000000
# 8649581 valid read align count
# 8649581 unique umi count
# 2233868 mapped unique library members
# 1470076 mapped proximal 1 RNA reads
# 396330 mapped proximal 2 RNA reads
# 4774214 mapped distal RNA reads
# 75000000
# 8745102 valid read align count
# 8745102 unique umi count
# 2237355 mapped unique library members
# 1484499 mapped proximal 1 RNA reads
# 400042 mapped proximal 2 RNA reads
# 4833527 mapped distal RNA reads
# 76000000
# 8847323 valid read align count
# 8847323 unique umi count
# 2239456 mapped unique library members
# 1506177 mapped proximal 1 RNA reads
# 405613 mapped proximal 2 RNA reads
# 4878773 mapped distal RNA reads
# 77000000
# 8944028 valid read align count
# 8944028 unique umi count
# 2241406 mapped unique library members
# 1528151 mapped proximal 1 RNA reads
# 411223 mapped proximal 2 RNA reads
# 4918172 mapped distal RNA reads
# 78000000
# 9047823 valid read align count
# 9047823 unique umi count
# 2243491 mapped unique library members
# 1549813 mapped proximal 1 RNA reads
# 416859 mapped proximal 2 RNA reads
# 4964849 mapped distal RNA reads
# 79000000
# 9155204 valid read align count
# 9155204 unique umi count
# 2245638 mapped unique library members
# 1571458 mapped proximal 1 RNA reads
# 422580 mapped proximal 2 RNA reads
# 5015258 mapped distal RNA reads
# 80000000
# 9259425 valid read align count
# 9259425 unique umi count
# 2247678 mapped unique library members
# 1592893 mapped proximal 1 RNA reads
# 428186 mapped proximal 2 RNA reads
# 5063387 mapped distal RNA reads
# 81000000
# 9359136 valid read align count
# 9359136 unique umi count
# 2249596 mapped unique library members
# 1614291 mapped proximal 1 RNA reads
# 433469 mapped proximal 2 RNA reads
# 5108107 mapped distal RNA reads
# 82000000
# 9437863 valid read align count
# 9437863 unique umi count
# 2251572 mapped unique library members
# 1632477 mapped proximal 1 RNA reads
# 437595 mapped proximal 2 RNA reads
# 5145125 mapped distal RNA reads
# 83000000
# 9552642 valid read align count
# 9552642 unique umi count
# 2254388 mapped unique library members
# 1649431 mapped proximal 1 RNA reads
# 442332 mapped proximal 2 RNA reads
# 5215213 mapped distal RNA reads
# 84000000
# 9657149 valid read align count
# 9657149 unique umi count
# 2256239 mapped unique library members
# 1670936 mapped proximal 1 RNA reads
# 447894 mapped proximal 2 RNA reads
# 5263091 mapped distal RNA reads
# 85000000
# 9760492 valid read align count
# 9760492 unique umi count
# 2257943 mapped unique library members
# 1692535 mapped proximal 1 RNA reads
# 453535 mapped proximal 2 RNA reads
# 5309220 mapped distal RNA reads
# 86000000
# 9866655 valid read align count
# 9866655 unique umi count
# 2259763 mapped unique library members
# 1713867 mapped proximal 1 RNA reads
# 459250 mapped proximal 2 RNA reads
# 5358422 mapped distal RNA reads
# 87000000
# 9976125 valid read align count
# 9976125 unique umi count
# 2261515 mapped unique library members
# 1735188 mapped proximal 1 RNA reads
# 464924 mapped proximal 2 RNA reads
# 5411207 mapped distal RNA reads
# 88000000
# 10087825 valid read align count
# 10087825 unique umi count
# 2263420 mapped unique library members
# 1756404 mapped proximal 1 RNA reads
# 470597 mapped proximal 2 RNA reads
# 5466677 mapped distal RNA reads
# 89000000
# 10195526 valid read align count
# 10195526 unique umi count
# 2265178 mapped unique library members
# 1777542 mapped proximal 1 RNA reads
# 475936 mapped proximal 2 RNA reads
# 5518937 mapped distal RNA reads
# 90000000
# 10269178 valid read align count
# 10269178 unique umi count
# 2266862 mapped unique library members
# 1794257 mapped proximal 1 RNA reads
# 479790 mapped proximal 2 RNA reads
# 5554270 mapped distal RNA reads
# 91000000
# 10389799 valid read align count
# 10389799 unique umi count
# 2269113 mapped unique library members
# 1812957 mapped proximal 1 RNA reads
# 484840 mapped proximal 2 RNA reads
# 5625462 mapped distal RNA reads
# 92000000
# 10491921 valid read align count
# 10491921 unique umi count
# 2270567 mapped unique library members
# 1834425 mapped proximal 1 RNA reads
# 490475 mapped proximal 2 RNA reads
# 5670691 mapped distal RNA reads
# 93000000
# 10593673 valid read align count
# 10593673 unique umi count
# 2272006 mapped unique library members
# 1856148 mapped proximal 1 RNA reads
# 496126 mapped proximal 2 RNA reads
# 5715078 mapped distal RNA reads
# 94000000
# 10702309 valid read align count
# 10702309 unique umi count
# 2273570 mapped unique library members
# 1877544 mapped proximal 1 RNA reads
# 501839 mapped proximal 2 RNA reads
# 5766753 mapped distal RNA reads
# 95000000
# 10813290 valid read align count
# 10813290 unique umi count
# 2275141 mapped unique library members
# 1898682 mapped proximal 1 RNA reads
# 507468 mapped proximal 2 RNA reads
# 5821262 mapped distal RNA reads
# 96000000
# 10924713 valid read align count
# 10924713 unique umi count
# 2276746 mapped unique library members
# 1919636 mapped proximal 1 RNA reads
# 513086 mapped proximal 2 RNA reads
# 5876823 mapped distal RNA reads
# 97000000
# 11030952 valid read align count
# 11030952 unique umi count
# 2278275 mapped unique library members
# 1940368 mapped proximal 1 RNA reads
# 518450 mapped proximal 2 RNA reads
# 5927943 mapped distal RNA reads
# 98000000
# 11104745 valid read align count
# 11104745 unique umi count
# 2279830 mapped unique library members
# 1956949 mapped proximal 1 RNA reads
# 522298 mapped proximal 2 RNA reads
# 5962436 mapped distal RNA reads
# 99000000
# 11225602 valid read align count
# 11225602 unique umi count
# 2281590 mapped unique library members
# 1976840 mapped proximal 1 RNA reads
# 527833 mapped proximal 2 RNA reads
# 6029978 mapped distal RNA reads
# 100000000
# 11355525 valid read align count
# 11355525 unique umi count
# 2283419 mapped unique library members
# 1997366 mapped proximal 1 RNA reads
# 533510 mapped proximal 2 RNA reads
# 6104701 mapped distal RNA reads
# 101000000
# 11493306 valid read align count
# 11493306 unique umi count
# 2285446 mapped unique library members
# 2017677 mapped proximal 1 RNA reads
# 539185 mapped proximal 2 RNA reads
# 6187248 mapped distal RNA reads
# 102000000
# 11608374 valid read align count
# 11608374 unique umi count
# 2286940 mapped unique library members
# 2038873 mapped proximal 1 RNA reads
# 544600 mapped proximal 2 RNA reads
# 6246454 mapped distal RNA reads
# 103000000
# 11731034 valid read align count
# 11731034 unique umi count
# 2288505 mapped unique library members
# 2059833 mapped proximal 1 RNA reads
# 550265 mapped proximal 2 RNA reads
# 6313434 mapped distal RNA reads
# 104000000
# 11843407 valid read align count
# 11843407 unique umi count
# 2290027 mapped unique library members
# 2079298 mapped proximal 1 RNA reads
# 555351 mapped proximal 2 RNA reads
# 6374895 mapped distal RNA reads
# 105000000
# 11890134 valid read align count
# 11890134 unique umi count
# 2291196 mapped unique library members
# 2090473 mapped proximal 1 RNA reads
# 558251 mapped proximal 2 RNA reads
# 6395593 mapped distal RNA reads
# 106000000
# 12000129 valid read align count
# 12000129 unique umi count
# 2292546 mapped unique library members
# 2111065 mapped proximal 1 RNA reads
# 563599 mapped proximal 2 RNA reads
# 6453068 mapped distal RNA reads
# 107000000
# 12148366 valid read align count
# 12148366 unique umi count
# 2294394 mapped unique library members
# 2131101 mapped proximal 1 RNA reads
# 569322 mapped proximal 2 RNA reads
# 6546956 mapped distal RNA reads
# 108000000
# 12300367 valid read align count
# 12300367 unique umi count
# 2296380 mapped unique library members
# 2151073 mapped proximal 1 RNA reads
# 575103 mapped proximal 2 RNA reads
# 6644516 mapped distal RNA reads
# 109000000
# 12447904 valid read align count
# 12447904 unique umi count
# 2298139 mapped unique library members
# 2170836 mapped proximal 1 RNA reads
# 580895 mapped proximal 2 RNA reads
# 6737613 mapped distal RNA reads
# 110000000
# 12573610 valid read align count
# 12573610 unique umi count
# 2299532 mapped unique library members
# 2191991 mapped proximal 1 RNA reads
# 586640 mapped proximal 2 RNA reads
# 6807333 mapped distal RNA reads
# 111000000
# 12707832 valid read align count
# 12707832 unique umi count
# 2301075 mapped unique library members
# 2212440 mapped proximal 1 RNA reads
# 592305 mapped proximal 2 RNA reads
# 6886543 mapped distal RNA reads
# 112000000
# 12835173 valid read align count
# 12835173 unique umi count
# 2302537 mapped unique library members
# 2231747 mapped proximal 1 RNA reads
# 597471 mapped proximal 2 RNA reads
# 6963077 mapped distal RNA reads
# 113000000
# 12891054 valid read align count
# 12891054 unique umi count
# 2303500 mapped unique library members
# 2243798 mapped proximal 1 RNA reads
# 600448 mapped proximal 2 RNA reads
# 6989998 mapped distal RNA reads
# 114000000
# 13009877 valid read align count
# 13009877 unique umi count
# 2304704 mapped unique library members
# 2264752 mapped proximal 1 RNA reads
# 606032 mapped proximal 2 RNA reads
# 7053546 mapped distal RNA reads
# 115000000
# 13144939 valid read align count
# 13144939 unique umi count
# 2306035 mapped unique library members
# 2285215 mapped proximal 1 RNA reads
# 611810 mapped proximal 2 RNA reads
# 7133397 mapped distal RNA reads
# 116000000
# 13284510 valid read align count
# 13284510 unique umi count
# 2307459 mapped unique library members
# 2305478 mapped proximal 1 RNA reads
# 617706 mapped proximal 2 RNA reads
# 7217575 mapped distal RNA reads
# 117000000
# 13424757 valid read align count
# 13424757 unique umi count
# 2308891 mapped unique library members
# 2325717 mapped proximal 1 RNA reads
# 623565 mapped proximal 2 RNA reads
# 7302636 mapped distal RNA reads
# 118000000
# 13551110 valid read align count
# 13551110 unique umi count
# 2310070 mapped unique library members
# 2346751 mapped proximal 1 RNA reads
# 629115 mapped proximal 2 RNA reads
# 7373189 mapped distal RNA reads
# 119000000
# 13682059 valid read align count
# 13682059 unique umi count
# 2311282 mapped unique library members
# 2367396 mapped proximal 1 RNA reads
# 634957 mapped proximal 2 RNA reads
# 7448444 mapped distal RNA reads
# 120000000
# 13797149 valid read align count
# 13797149 unique umi count
# 2312493 mapped unique library members
# 2386180 mapped proximal 1 RNA reads
# 639920 mapped proximal 2 RNA reads
# 7514153 mapped distal RNA reads
# 121000000
# 13846241 valid read align count
# 13846241 unique umi count
# 2313274 mapped unique library members
# 2397573 mapped proximal 1 RNA reads
# 642870 mapped proximal 2 RNA reads
# 7534490 mapped distal RNA reads
# 122000000
# 13954727 valid read align count
# 13954727 unique umi count
# 2314170 mapped unique library members
# 2418547 mapped proximal 1 RNA reads
# 648320 mapped proximal 2 RNA reads
# 7587565 mapped distal RNA reads
# 123000000
# 14078321 valid read align count
# 14078321 unique umi count
# 2315202 mapped unique library members
# 2439353 mapped proximal 1 RNA reads
# 654035 mapped proximal 2 RNA reads
# 7655252 mapped distal RNA reads
# 124000000
# 14205827 valid read align count
# 14205827 unique umi count
# 2316248 mapped unique library members
# 2460039 mapped proximal 1 RNA reads
# 659776 mapped proximal 2 RNA reads
# 7726606 mapped distal RNA reads
# 125000000
# 14336181 valid read align count
# 14336181 unique umi count
# 2317309 mapped unique library members
# 2480515 mapped proximal 1 RNA reads
# 665587 mapped proximal 2 RNA reads
# 7801517 mapped distal RNA reads
# 126000000
# 14452905 valid read align count
# 14452905 unique umi count
# 2318225 mapped unique library members
# 2501499 mapped proximal 1 RNA reads
# 671128 mapped proximal 2 RNA reads
# 7862226 mapped distal RNA reads
# 127000000
# 14572103 valid read align count
# 14572103 unique umi count
# 2319134 mapped unique library members
# 2522513 mapped proximal 1 RNA reads
# 676828 mapped proximal 2 RNA reads
# 7924990 mapped distal RNA reads
# 128000000
# 14682713 valid read align count
# 14682713 unique umi count
# 2320019 mapped unique library members
# 2542140 mapped proximal 1 RNA reads
# 682034 mapped proximal 2 RNA reads
# 7983605 mapped distal RNA reads
# 129000000
# 14734874 valid read align count
# 14734874 unique umi count
# 2320602 mapped unique library members
# 2556366 mapped proximal 1 RNA reads
# 685324 mapped proximal 2 RNA reads
# 8003164 mapped distal RNA reads
# 130000000
# 14833536 valid read align count
# 14833536 unique umi count
# 2321269 mapped unique library members
# 2577725 mapped proximal 1 RNA reads
# 690655 mapped proximal 2 RNA reads
# 8046850 mapped distal RNA reads
# 131000000
# 14973851 valid read align count
# 14973851 unique umi count
# 2322354 mapped unique library members
# 2598217 mapped proximal 1 RNA reads
# 696513 mapped proximal 2 RNA reads
# 8131846 mapped distal RNA reads
# 132000000
# 15115350 valid read align count
# 15115350 unique umi count
# 2323393 mapped unique library members
# 2618646 mapped proximal 1 RNA reads
# 702212 mapped proximal 2 RNA reads
# 8218380 mapped distal RNA reads
# 133000000
# 15259293 valid read align count
# 15259293 unique umi count
# 2324473 mapped unique library members
# 2638832 mapped proximal 1 RNA reads
# 708069 mapped proximal 2 RNA reads
# 8306792 mapped distal RNA reads
# 134000000
# 15382173 valid read align count
# 15382173 unique umi count
# 2325323 mapped unique library members
# 2659756 mapped proximal 1 RNA reads
# 713875 mapped proximal 2 RNA reads
# 8373061 mapped distal RNA reads
# 135000000
# 15504102 valid read align count
# 15504102 unique umi count
# 2326112 mapped unique library members
# 2680913 mapped proximal 1 RNA reads
# 719801 mapped proximal 2 RNA reads
# 8438270 mapped distal RNA reads
# 136000000
# 15633029 valid read align count
# 15633029 unique umi count
# 2326974 mapped unique library members
# 2701738 mapped proximal 1 RNA reads
# 725533 mapped proximal 2 RNA reads
# 8511072 mapped distal RNA reads
# 137000000
# 15695065 valid read align count
# 15695065 unique umi count
# 2327575 mapped unique library members
# 2714962 mapped proximal 1 RNA reads
# 728654 mapped proximal 2 RNA reads
# 8540869 mapped distal RNA reads
# 138000000
# 15786509 valid read align count
# 15786509 unique umi count
# 2328124 mapped unique library members
# 2736481 mapped proximal 1 RNA reads
# 733677 mapped proximal 2 RNA reads
# 8578930 mapped distal RNA reads
# 139000000
# 15902653 valid read align count
# 15902653 unique umi count
# 2328799 mapped unique library members
# 2757461 mapped proximal 1 RNA reads
# 739318 mapped proximal 2 RNA reads
# 8638858 mapped distal RNA reads
# 140000000
# 16031376 valid read align count
# 16031376 unique umi count
# 2329614 mapped unique library members
# 2778437 mapped proximal 1 RNA reads
# 745129 mapped proximal 2 RNA reads
# 8711330 mapped distal RNA reads
# 141000000
# 16162107 valid read align count
# 16162107 unique umi count
# 2330368 mapped unique library members
# 2799153 mapped proximal 1 RNA reads
# 750826 mapped proximal 2 RNA reads
# 8786271 mapped distal RNA reads
# 142000000
# 16290762 valid read align count
# 16290762 unique umi count
# 2331166 mapped unique library members
# 2819987 mapped proximal 1 RNA reads
# 756532 mapped proximal 2 RNA reads
# 8858987 mapped distal RNA reads
# 143000000
# 16410841 valid read align count
# 16410841 unique umi count
# 2331875 mapped unique library members
# 2840930 mapped proximal 1 RNA reads
# 762173 mapped proximal 2 RNA reads
# 8922913 mapped distal RNA reads
# 144000000
# 16534765 valid read align count
# 16534765 unique umi count
# 2332575 mapped unique library members
# 2861830 mapped proximal 1 RNA reads
# 767721 mapped proximal 2 RNA reads
# 8990908 mapped distal RNA reads
# 145000000
# 16620997 valid read align count
# 16620997 unique umi count
# 2333166 mapped unique library members
# 2877093 mapped proximal 1 RNA reads
# 771801 mapped proximal 2 RNA reads
# 9036581 mapped distal RNA reads
# 146000000
# 16691546 valid read align count
# 16691546 unique umi count
# 2333598 mapped unique library members
# 2894485 mapped proximal 1 RNA reads
# 775877 mapped proximal 2 RNA reads
# 9066505 mapped distal RNA reads
# 147000000
# 16796444 valid read align count
# 16796444 unique umi count
# 2334163 mapped unique library members
# 2915545 mapped proximal 1 RNA reads
# 781163 mapped proximal 2 RNA reads
# 9116556 mapped distal RNA reads
# 148000000
# 16911577 valid read align count
# 16911577 unique umi count
# 2334851 mapped unique library members
# 2935611 mapped proximal 1 RNA reads
# 786223 mapped proximal 2 RNA reads
# 9180997 mapped distal RNA reads
# 149000000
# 17012015 valid read align count
# 17012015 unique umi count
# 2335660 mapped unique library members
# 2952853 mapped proximal 1 RNA reads
# 790415 mapped proximal 2 RNA reads
# 9241156 mapped distal RNA reads
# 150000000
# 17122065 valid read align count
# 17122065 unique umi count
# 2336280 mapped unique library members
# 2972753 mapped proximal 1 RNA reads
# 795503 mapped proximal 2 RNA reads
# 9299563 mapped distal RNA reads
# 151000000
# 17248098 valid read align count
# 17248098 unique umi count
# 2336953 mapped unique library members
# 2993265 mapped proximal 1 RNA reads
# 801149 mapped proximal 2 RNA reads
# 9370344 mapped distal RNA reads
# 152000000
# 17374563 valid read align count
# 17374563 unique umi count
# 2337621 mapped unique library members
# 3013727 mapped proximal 1 RNA reads
# 806672 mapped proximal 2 RNA reads
# 9442117 mapped distal RNA reads
# 153000000
# 17481071 valid read align count
# 17481071 unique umi count
# 2338142 mapped unique library members
# 3035091 mapped proximal 1 RNA reads
# 812192 mapped proximal 2 RNA reads
# 9492125 mapped distal RNA reads
# 154000000
# 17588246 valid read align count
# 17588246 unique umi count
# 2338617 mapped unique library members
# 3056324 mapped proximal 1 RNA reads
# 817837 mapped proximal 2 RNA reads
# 9542925 mapped distal RNA reads
# 155000000
# 17710449 valid read align count
# 17710449 unique umi count
# 2339239 mapped unique library members
# 3077215 mapped proximal 1 RNA reads
# 823385 mapped proximal 2 RNA reads
# 9609668 mapped distal RNA reads
# 156000000
# 17840087 valid read align count
# 17840087 unique umi count
# 2339952 mapped unique library members
# 3097040 mapped proximal 1 RNA reads
# 828642 mapped proximal 2 RNA reads
# 9687770 mapped distal RNA reads
# 157000000
# 17941421 valid read align count
# 17941421 unique umi count
# 2340676 mapped unique library members
# 3114143 mapped proximal 1 RNA reads
# 832732 mapped proximal 2 RNA reads
# 9749199 mapped distal RNA reads
# 158000000
# 18064708 valid read align count
# 18064708 unique umi count
# 2341262 mapped unique library members
# 3134699 mapped proximal 1 RNA reads
# 838285 mapped proximal 2 RNA reads
# 9817620 mapped distal RNA reads
# 159000000
# 18195263 valid read align count
# 18195263 unique umi count
# 2341862 mapped unique library members
# 3155171 mapped proximal 1 RNA reads
# 843903 mapped proximal 2 RNA reads
# 9893357 mapped distal RNA reads
# 160000000
# 18332606 valid read align count
# 18332606 unique umi count
# 2342486 mapped unique library members
# 3175770 mapped proximal 1 RNA reads
# 849449 mapped proximal 2 RNA reads
# 9975822 mapped distal RNA reads
# 161000000
# 18452408 valid read align count
# 18452408 unique umi count
# 2342989 mapped unique library members
# 3196626 mapped proximal 1 RNA reads
# 855103 mapped proximal 2 RNA reads
# 10039625 mapped distal RNA reads
# 162000000
# 18569839 valid read align count
# 18569839 unique umi count
# 2343484 mapped unique library members
# 3217396 mapped proximal 1 RNA reads
# 860800 mapped proximal 2 RNA reads
# 10101067 mapped distal RNA reads
# 163000000
# 18692583 valid read align count
# 18692583 unique umi count
# 2344015 mapped unique library members
# 3238199 mapped proximal 1 RNA reads
# 866483 mapped proximal 2 RNA reads
# 10168196 mapped distal RNA reads
# 164000000
# 18815752 valid read align count
# 18815752 unique umi count
# 2344621 mapped unique library members
# 3258397 mapped proximal 1 RNA reads
# 871798 mapped proximal 2 RNA reads
# 10238269 mapped distal RNA reads
# 165000000
# 18924769 valid read align count
# 18924769 unique umi count
# 2345286 mapped unique library members
# 3277588 mapped proximal 1 RNA reads
# 876421 mapped proximal 2 RNA reads
# 10301763 mapped distal RNA reads
# 166000000
# 19029314 valid read align count
# 19029314 unique umi count
# 2345722 mapped unique library members
# 3297341 mapped proximal 1 RNA reads
# 881626 mapped proximal 2 RNA reads
# 10355273 mapped distal RNA reads
# 167000000
# 19148930 valid read align count
# 19148930 unique umi count
# 2346194 mapped unique library members
# 3318707 mapped proximal 1 RNA reads
# 887376 mapped proximal 2 RNA reads
# 10418204 mapped distal RNA reads
# 168000000
# 19276652 valid read align count
# 19276652 unique umi count
# 2346701 mapped unique library members
# 3339636 mapped proximal 1 RNA reads
# 893079 mapped proximal 2 RNA reads
# 10489882 mapped distal RNA reads
# 169000000
# 19387315 valid read align count
# 19387315 unique umi count
# 2347087 mapped unique library members
# 3361054 mapped proximal 1 RNA reads
# 898750 mapped proximal 2 RNA reads
# 10543722 mapped distal RNA reads
# 170000000
# 19491354 valid read align count
# 19491354 unique umi count
# 2347427 mapped unique library members
# 3382768 mapped proximal 1 RNA reads
# 904610 mapped proximal 2 RNA reads
# 10590175 mapped distal RNA reads
# 171000000
# 19598134 valid read align count
# 19598134 unique umi count
# 2347778 mapped unique library members
# 3404149 mapped proximal 1 RNA reads
# 910227 mapped proximal 2 RNA reads
# 10640491 mapped distal RNA reads
# 172000000
# 19705552 valid read align count
# 19705552 unique umi count
# 2348170 mapped unique library members
# 3424859 mapped proximal 1 RNA reads
# 915417 mapped proximal 2 RNA reads
# 10694541 mapped distal RNA reads
# 173000000
# 19799660 valid read align count
# 19799660 unique umi count
# 2348573 mapped unique library members
# 3443891 mapped proximal 1 RNA reads
# 919883 mapped proximal 2 RNA reads
# 10744283 mapped distal RNA reads
# 174000000
# 19893510 valid read align count
# 19893510 unique umi count
# 2348981 mapped unique library members
# 3462862 mapped proximal 1 RNA reads
# 924642 mapped proximal 2 RNA reads
# 10790333 mapped distal RNA reads
# 175000000
# 20006214 valid read align count
# 20006214 unique umi count
# 2349381 mapped unique library members
# 3484004 mapped proximal 1 RNA reads
# 930355 mapped proximal 2 RNA reads
# 10846921 mapped distal RNA reads
# 176000000
# 20122767 valid read align count
# 20122767 unique umi count
# 2349772 mapped unique library members
# 3504893 mapped proximal 1 RNA reads
# 935869 mapped proximal 2 RNA reads
# 10908023 mapped distal RNA reads
# 177000000
# 20226955 valid read align count
# 20226955 unique umi count
# 2350082 mapped unique library members
# 3526372 mapped proximal 1 RNA reads
# 941337 mapped proximal 2 RNA reads
# 10955602 mapped distal RNA reads
# 178000000
# 20328233 valid read align count
# 20328233 unique umi count
# 2350390 mapped unique library members
# 3548164 mapped proximal 1 RNA reads
# 946872 mapped proximal 2 RNA reads
# 11000409 mapped distal RNA reads
# 179000000
# 20439955 valid read align count
# 20439955 unique umi count
# 2350757 mapped unique library members
# 3569393 mapped proximal 1 RNA reads
# 952399 mapped proximal 2 RNA reads
# 11055951 mapped distal RNA reads
# 180000000
# 20570039 valid read align count
# 20570039 unique umi count
# 2351254 mapped unique library members
# 3589383 mapped proximal 1 RNA reads
# 957708 mapped proximal 2 RNA reads
# 11132523 mapped distal RNA reads
# 181000000
# 20682758 valid read align count
# 20682758 unique umi count
# 2351719 mapped unique library members
# 3608354 mapped proximal 1 RNA reads
# 962418 mapped proximal 2 RNA reads
# 11198455 mapped distal RNA reads
# 182000000
# 20783966 valid read align count
# 20783966 unique umi count
# 2352113 mapped unique library members
# 3627363 mapped proximal 1 RNA reads
# 967166 mapped proximal 2 RNA reads
# 11250463 mapped distal RNA reads
# 183000000
# 20905851 valid read align count
# 20905851 unique umi count
# 2352487 mapped unique library members
# 3648254 mapped proximal 1 RNA reads
# 972939 mapped proximal 2 RNA reads
# 11316410 mapped distal RNA reads
# 184000000
# 21036457 valid read align count
# 21036457 unique umi count
# 2352943 mapped unique library members
# 3668741 mapped proximal 1 RNA reads
# 978633 mapped proximal 2 RNA reads
# 11391973 mapped distal RNA reads
# 185000000
# 21151803 valid read align count
# 21151803 unique umi count
# 2353269 mapped unique library members
# 3690118 mapped proximal 1 RNA reads
# 984263 mapped proximal 2 RNA reads
# 11450567 mapped distal RNA reads
# 186000000
# 21263351 valid read align count
# 21263351 unique umi count
# 2353586 mapped unique library members
# 3711753 mapped proximal 1 RNA reads
# 989753 mapped proximal 2 RNA reads
# 11505484 mapped distal RNA reads
# 187000000
# 21375432 valid read align count
# 21375432 unique umi count
# 2353893 mapped unique library members
# 3732773 mapped proximal 1 RNA reads
# 995426 mapped proximal 2 RNA reads
# 11560945 mapped distal RNA reads
# 188000000
# 21499037 valid read align count
# 21499037 unique umi count
# 2354260 mapped unique library members
# 3753305 mapped proximal 1 RNA reads
# 1000891 mapped proximal 2 RNA reads
# 11629464 mapped distal RNA reads
# 189000000
# 21618013 valid read align count
# 21618013 unique umi count
# 2354622 mapped unique library members
# 3773626 mapped proximal 1 RNA reads
# 1006167 mapped proximal 2 RNA reads
# 11694327 mapped distal RNA reads
# 190000000
# 21709634 valid read align count
# 21709634 unique umi count
# 2354989 mapped unique library members
# 3792735 mapped proximal 1 RNA reads
# 1010618 mapped proximal 2 RNA reads
# 11740686 mapped distal RNA reads
# 191000000
# 21816890 valid read align count
# 21816890 unique umi count
# 2355291 mapped unique library members
# 3813701 mapped proximal 1 RNA reads
# 1016482 mapped proximal 2 RNA reads
# 11790981 mapped distal RNA reads
# 192000000
# 21931873 valid read align count
# 21931873 unique umi count
# 2355631 mapped unique library members
# 3834642 mapped proximal 1 RNA reads
# 1022286 mapped proximal 2 RNA reads
# 11849758 mapped distal RNA reads
# 193000000
# 22044459 valid read align count
# 22044459 unique umi count
# 2355955 mapped unique library members
# 3855619 mapped proximal 1 RNA reads
# 1027731 mapped proximal 2 RNA reads
# 11907380 mapped distal RNA reads
# 194000000
# 22146105 valid read align count
# 22146105 unique umi count
# 2356192 mapped unique library members
# 3877774 mapped proximal 1 RNA reads
# 1033535 mapped proximal 2 RNA reads
# 11950857 mapped distal RNA reads
# 195000000
# 22245957 valid read align count
# 22245957 unique umi count
# 2356397 mapped unique library members
# 3899444 mapped proximal 1 RNA reads
# 1039235 mapped proximal 2 RNA reads
# 11992799 mapped distal RNA reads
# COMPLETE
# 2356535 mapped unique library members
# 3911223 mapped proximal 1 RNA reads
# 1042220 mapped proximal 2 RNA reads
# 12014785 mapped distal RNA reads
# 2212115 kept library members
# 2212115
